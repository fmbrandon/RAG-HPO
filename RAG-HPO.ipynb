# %% [markdown]
# # RAG-HPO annotation example
#
# This notebook demonstrates the installed package. It does not contain application logic or persist credentials.

# %%
from pathlib import Path

from rag_hpo.doctor import run_doctor

report = run_doctor(
    vector_dir=None,
    output_dir=Path("rag_hpo_output"),
    check_provider=False,
)
print(report.model_dump())

# %% [markdown]
# After generating vector artifacts and setting `RAG_HPO_API_KEY`, annotate a CSV with:
#
# ```bash
# rag-hpo annotate --input Test_Cases.csv --vector-dir artifacts/hpo --output-dir rag_hpo_output
# ```
#
# Use only data approved for transmission to the configured provider.
